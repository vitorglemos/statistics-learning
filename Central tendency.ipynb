# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
df = pd.read_csv("titanic_train.csv")

df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
central_tendency = {'mode': int(df["Age"].mode()),
                    'mean': df["Age"].mean(),
                    'median': int(df["Age"].median()),
                    'std': df["Age"].std()}

# %%
print(central_tendency)
# Out:
# {'mode': 24, 'mean': 29.69911764705882, 'median': 28, 'std': 14.526497332334042}

# %%
ax = df["Age"].plot.hist()

# %% [markdown]
# ## Spearman Correlation

# %%
df.corr('spearman')
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.034091  0.041010 -0.061161  0.001235
# Survived       -0.005007  1.000000 -0.339668 -0.052565  0.088879  0.138266
# Pclass         -0.034091 -0.339668  1.000000 -0.361666 -0.043019 -0.022801
# Age             0.041010 -0.052565 -0.361666  1.000000 -0.182061 -0.254212
# SibSp          -0.061161  0.088879 -0.043019 -0.182061  1.000000  0.450014
# Parch           0.001235  0.138266 -0.022801 -0.254212  0.450014  1.000000
# Fare           -0.013975  0.323736 -0.688032  0.135051  0.447113  0.410074
#
#                  Fare
# PassengerId -0.013975
# Survived     0.323736
# Pclass      -0.688032
# Age          0.135051
# SibSp        0.447113
# Parch        0.410074
# Fare         1.000000

# %%
fig = plt.figure(figsize=(6, 6))

plt.matshow(df.corr(), fignum=f.number)
plt.xticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=12, 
           rotation=45)
plt.yticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=12)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=12)
plt.title('Correlation Matrix', fontsize=14);

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_01243_row0_col0,#T_01243_row1_col1,#T_01243_row2_col2,#T_01243_row3_col3,#T_01243_row4_col4,#T_01243_row5_col5,#T_01243_row6_col6{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_01243_row0_col1{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_01243_row0_col2{
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }#T_01243_row0_col3{
#             background-color:  #9dbdff;
#             color:  #000000;
#         }#T_01243_row0_col4,#T_01243_row3_col1{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_01243_row0_col5{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_01243_row0_col6{
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }#T_01243_row1_col0{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
# ...

# %%
df.plot.scatter(x='Age', y='Parch', title= "Scatter plot between two variables X and Y");
plt.show(block=True);

# %%
boxplot = df.boxplot(column=['Age', 'SibSp', 'Fare'])
